# %% [markdown]
# # Analysis of the frequency of transitions in the replay buffer

# %%
import marl
import matplotlib.pyplot as plt

plt.rcParams.update(
    {
        "text.usetex": False,
        "font.family": "serif",
        #'font.serif': ['Latin Modern Roman'],  # Replace with the specific font used in your beamer poster
        #'font.sans-serif': ['Latin Modern Sans'],
        "font.size": 10,  # in beamer
    }
)

# %%
import polars as pl

exp = marl.LightExperiment.load("logs/LLE-lvl6-VDN-BM-10000-f1.0/")

tests = []
for run in exp.runs:
    run.train_metrics
